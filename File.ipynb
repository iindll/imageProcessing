# %%
#Threshold
import os,cv2
image = cv2.imread("./data/horse.jpeg")
gray_img = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
ret ,Threshold = cv2.threshold(gray_img,80,255,cv2.THRESH_BINARY)
Threshold = cv2.blur(Threshold , (10,10))
ret ,Threshold = cv2.threshold(gray_img,180,255,cv2.THRESH_BINARY)

cv2.imshow("image",Threshold)

cv2.waitKey(0)
# Out:
# -1

# %%
import os,cv2
image = cv2.imread("./data/hand.jpeg")
gray_img = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
# ret ,Threshold = cv2.threshold(gray_img,140,255,cv2.THRESH_BINARY)
Threshold = cv2.adaptiveThreshold(gray_img ,255 , cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,20)
cv2.imshow("image",Threshold)
cv2.imshow("N-image",image)

cv2.waitKey(0)
# Out:
# -1

# %%
import os,cv2
import numpy as np
image = cv2.imread("./data/basketball.jpeg")
canny_img = cv2.Canny(image , 100, 200)
canny_img3 = cv2.Canny(image , 200, 400)
canny_img2= cv2.Canny(image , 50, 350)
canny_img1= cv2.Canny(image , 400, 700)

# median_val = np.median(image)

# lower = int(max(0, 0.66 * median_val))
# upper = int(min(255, 1.33 * median_val))

img_edged = cv2.dilate(canny_img,np.ones((2,2),dtype=np.int8))
img_edged_e = cv2.erode(img_edged,np.ones((10,10),dtype=np.int8))

cv2.imshow("image",canny_img)
cv2.imshow("edged" , img_edged)
cv2.imshow("image1",img_edged_e)
# cv2.imshow("image2",canny_img2)
# cv2.imshow("image3",canny_img3)

cv2.waitKey(0)
# Out:
# -1

# %%
import os,cv2
image = cv2.imread("./data/ROCH.jpeg")
cv2.line(image , (100,100) , (300,450) , (0,255,0) , 3)
cv2.rectangle(image,(200,300),(400,400) , (140,200,255) , 2)
cv2.circle(image,(500,500),100,(34,69,100) , -1)
cv2.putText(image,"Hi" ,(499,234) , cv2.FONT_HERSHEY_COMPLEX ,2, (20,50,21) , 2 )
cv2.imshow("image",image)
cv2.waitKey(0)
# Out:
# -1

# %%
import os,cv2
image = cv2.imread("./data/birds.jpeg")
resized = cv2.resize(image, (600, 600)) 
gray_img = cv2.cvtColor(resized,cv2.COLOR_RGB2GRAY)
ret , thrers = cv2.threshold(gray_img , 100 ,255,cv2.THRESH_BINARY_INV)
Threshold = cv2.adaptiveThreshold(gray_img ,255 , cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,20)
# blur_img = cv2.blur(Threshold,(3,3))
# cv2.imshow("image",blur_img)
cv2.imshow("image",thrers)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2

image = cv2.imread("./data/brid.jpeg")
cv2.imshow("image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import os,cv2
image = cv2.imread("./data/noisejpeg.jpeg")
img_blure = cv2.blur(image,(9,9))
img_Gaussian = cv2.GaussianBlur(image,(9,9), 3)
img_Mblur = cv2.medianBlur(image,9)
cv2.imshow("image1", img_blure)
cv2.imshow("image2", img_Gaussian)
cv2.imshow("image3", img_Mblur)
cv2.imshow("image", image)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

webcam = cv2.VideoCapture(0)

try:
    while True:   # infinite loop
        ret, frame = webcam.read()
    
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        clear_output(wait=True)  
        plt.imshow(frame_rgb)
        plt.axis("off")
        display(plt.gcf())

        time.sleep(0)   

except KeyboardInterrupt:
    print("⏹ Stopped manually")

webcam.release()
# Out:
# ⏹ Stopped manually
